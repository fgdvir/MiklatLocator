# %%
import pandas as pd
from geopy.geocoders import GoogleV3
import pandas as pd

# %%
df = pd.read_excel('./Miklat_JER.xls')
df.columns = ['Neighborhood','Num', 'Street Address','activity_notes', 'type','size','other','other2']

is_active_map = ~df.activity_notes.str.contains('לא פעיל').fillna(False)
valid_miklat = df[is_active_map]
valid_miklat = valid_miklat.assign(address= 'ירושלים ' + valid_miklat['Street Address'] + ' ' + valid_miklat['Neighborhood'],
                                   name='Jerusalem' + valid_miklat['Num'].astype(str))
valid_miklat
# Out:
#     Neighborhood  Num  Street Address activity_notes  type size  other  \
# 1         בוכרים  609     ישא ברכה 23            NaN  מקלט  250    NaN
# 2         בוכרים  612         יואל 16            NaN  מחסה   50    NaN
# 3         בוכרים  837  שמואל הנביא 79            NaN  מקלט  115    NaN
# 4         בוכרים  910       עובדיה 22            NaN  מקלט  100    NaN
# 5       בית הכרם  744         הבנאי 4            NaN  מקלט  170    NaN
# ..           ...  ...             ...            ...   ...  ...    ...
# 155       תלפיות  688        אפרתה 18            NaN  מקלט  200    NaN
# 156       תלפיות  689    בן גבריאל 34            NaN  מקלט   90    NaN
# 157       תלפיות  690       קלוזנר 12            NaN  מקלט  240    NaN
# 158       תלפיות  691  דרך בית לחם 93            NaN  מקלט  440    NaN
# 159       תלפיות  940   שלום יהודה 17            NaN  מקלט  100    NaN
#
#      other2                        address          name
# 1       NaN     ירושלים ישא ברכה 23 בוכרים  Jerusalem609
# ...

# %%
def get_lat_lng(address):
    geolocator = GoogleV3(api_key='AIzaSyAh_nkW37RFDN4SC3FPAUx4mJAUgNb8pW8')
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    return None, None  # Return None if geocoding failed

# Apply the function to the 'address' column
valid_miklat[['lat', 'lng']] = valid_miklat['address'].apply(lambda x: pd.Series(get_lat_lng(x)))

# Now df has two new columns 'lat' and 'lng' with the geocoded coordinates
valid_miklat
# Out:
#     Neighborhood  Num  Street Address activity_notes  type size  other  \
# 1         בוכרים  609     ישא ברכה 23            NaN  מקלט  250    NaN
# 2         בוכרים  612         יואל 16            NaN  מחסה   50    NaN
# 3         בוכרים  837  שמואל הנביא 79            NaN  מקלט  115    NaN
# 4         בוכרים  910       עובדיה 22            NaN  מקלט  100    NaN
# 5       בית הכרם  744         הבנאי 4            NaN  מקלט  170    NaN
# ..           ...  ...             ...            ...   ...  ...    ...
# 155       תלפיות  688        אפרתה 18            NaN  מקלט  200    NaN
# 156       תלפיות  689    בן גבריאל 34            NaN  מקלט   90    NaN
# 157       תלפיות  690       קלוזנר 12            NaN  מקלט  240    NaN
# 158       תלפיות  691  דרך בית לחם 93            NaN  מקלט  440    NaN
# 159       תלפיות  940   שלום יהודה 17            NaN  מקלט  100    NaN
#
#      other2                        address          name        lat        lng
# ...

# %%
valid_miklat.to_csv('miklat.csv', encoding='utf-8', index=False)

# %%
# Out:
# [{'name': 'Jerusalem609', 'address': {'lng': 35.2176755, 'lat': 31.7922354}},
#  {'name': 'Jerusalem612', 'address': {'lng': 35.21371, 'lat': 31.768319}},
#  {'name': 'Jerusalem837', 'address': {'lng': 35.2208356, 'lat': 31.794069}},
#  {'name': 'Jerusalem910', 'address': {'lng': 35.2156977, 'lat': 31.7903489}},
#  {'name': 'Jerusalem744', 'address': {'lng': 35.1904157, 'lat': 31.7750135}},
#  {'name': 'Jerusalem745', 'address': {'lng': 35.1922193, 'lat': 31.7774805}},
#  {'name': 'Jerusalem742', 'address': {'lng': 35.18298, 'lat': 31.7658063}},
#  {'name': 'Jerusalem743', 'address': {'lng': 35.1845249, 'lat': 31.7691802}},
#  {'name': 'Jerusalem\u200b908',
#   'address': {'lng': 35.2232357, 'lat': 31.79186859999999}},
#  {'name': 'Jerusalem841', 'address': {'lng': 35.2212159, 'lat': 31.7905408}},
#  {'name': 'Jerusalem\u200b984',
#   'address': {'lng': 35.22078700000001, 'lat': 31.759335}},
#  {'name': 'Jerusalem\u200b980',
# ...
